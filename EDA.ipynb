# %%
from pandas.plotting import scatter_matrix
import matplotlib.pyplot as plt

# %% [markdown]
# ### Data Analyst Workflow
#
# #### Distributions
# * histograms
# * cumulative distribution functions (CDFs)
# * Quantile-Quantille (Q-Q)
#
# #### Outliers
# #### Noise
# * confidence intervals
# * p-values
#
# #### Slice you data
# #### Consider practical significance
# * If you are unable to make sense of some user-agent strings in your logs, whether it represents 0.1% or 10% of the data makes a big difference in how much you should investigate those cases.
#
# #### Check for consistency over time
# * Remember the case in which the number of acounts decresed abruptally within days
#
# #### Acknowledge and count your filtering
# * Count the amount of data being filtered at each step.
# - "What fraction of queries did spam filtering remove?" (Depending on why you are filtering, that type of analysis may not always be possible.)

# %% [markdown]
# I think of data analysis as having three interrelated stages:
#
# Validation:1 Do I believe the data is self-consistent, that it was collected correctly, and that it represents what I think it does?
#
# Description: What's the objective interpretation of this data? For example, "Users make fewer queries classified as X," "In the experiment group, the time between X and Y is 1% larger," and "Fewer users go to the next page of results."
#
# Evaluation: Given the description, does the data tell us that something good is happening for the user, for Google, or for the world?

# %% [markdown]
# #### Schema Validation

# %%
# %sql
SELECT *
FROM turner_db.production.construction
LIMIT 5

# %% [markdown]
# #### Bussines questions:
#
# * Does the task with high level risk are more expensive in the cost material?
# * Does the labor require correlates with the task duration day?
# * Are the projects with a hight amount of days the one with the most
# start_constraint
# * Are the one with higher labor the one with more equipment and material cost
# * Which are the task with a hight dependecy count? (perhap you can use it in the dashboard, dependecy count as a filter)
#
# Note: You can add risk level to the scatter plots
#
# #### KPI's
#
# * Avg material cost (check for outliers) that afects the median value
# * Avg equipment units
# * Avg start constraint
# * Distribution by risk value (donut chart)
# * Avg resource constraint
# * Avg site constraint
#
# #### Follow up questions:
#
# * What does dependency count measures

# %% [markdown]
# ##### Better in performance when you want the whole table
#
# How it works: It reaches directly into the Databricks Metastore (like your turner_db.production.construction) and pulls the metadata.
#
# The Benefit: Since there is no "Raw SQL" string, Spark can validate that the table exists before it even tries to run the job.

# %%
# %python
#df = spark.read.table('turner_db.production.construction')
#display(df)
# Out:
# Databricks data profile. Run in Databricks to view.
# Databricks visualization. Run in Databricks to view.

# %%
# Best use when you have complex logic in your query

sql = """
SELECT *
FROM turner_db.production.construction"""

df = spark.sql(sql).toPandas()
display(df)

# %% [markdown]
# #### Missing values validation

# %% [markdown]
# There are not missing values in the data

# %%
df.info()

# %%
df.isna().sum()

# %%
df.shape

# %% [markdown]
# #### Duplicate check

# %% [markdown]
# #### Statistical Summary

# %% [markdown]
# **Task_Duration_Days**: The data has some spread for this specific feature but it is not that big. It is incredible to see a task that it only took one day. How much was the material cost and equipment units for it?

# %%
df.describe()

# %% [markdown]
# ##### check for outliers visually or mathematically

# %% [markdown]
# #### checking of the data points of 1 day in task duration

# %%
df[df['Task_Duration_Days'] == 1]

# %% [markdown]
# #### Analyzing distributions

# %% [markdown]
# I don't see outliers in the Material_Cost_USD feature

# %% [markdown]
# Why there is a peak of task that only last 1 day?

# %%
df['Task_Duration_Days'].plot(kind='hist', bins=15)

# %%
df['Material_Cost_USD'].plot(kind='hist', bins=15)

# %% [markdown]
# Why there is a dip in the labor required between the ranges 9 and 10?

# %%
df['Labor_Required'].plot(kind='hist', bins=10)

# %%
df['Labor_Required'].value_counts().sort_values().plot(kind='bar')

# %%
df['Equipment_Units'].plot(kind='hist', bins=10)

# %%
df['Equipment_Units'].value_counts().plot(kind='bar')

# %% [markdown]
# The majority of task are low level risk tasks, which are great news for the bussines.

# %%
df['Risk_Level'].value_counts().plot(kind='bar')

# %% [markdown]
# This means that each task doesn't depend to much in another task? another team? some permiss?

# %%
df['Dependency_Count'].value_counts().plot(kind='bar')

# %% [markdown]
# #### Checking for correlations

# %% [markdown]
# I don't see any correlations between fields by the pearson correlation. Just a small correlation of task duration day with the labor required and the site constrait_score.

# %%
df.corr(numeric_only=True)

# %% [markdown]
# Represent correlations graphically

# %% [markdown]
# The majority of the data falls into buckets

# %%
most_correlated_cols = ['Task_Duration_Days','Labor_Required', 'Site_Constraint_Score']
scatter_matrix(df[most_correlated_cols], figsize=(12, 8))
plt.show()
